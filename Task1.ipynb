# %%
from visualize import visualize

import warnings
warnings.filterwarnings('ignore')

# %%
REGION='IA_FullState'
#bounds object is in the form ([minx, maxx], [miny, maxy])
BOUNDS="([-10425171.940, -10423171.940], [5164494.710, 5166494.710])"
visualize(BOUNDS,REGION)
